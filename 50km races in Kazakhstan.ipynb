# %%
# https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
#import libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\yeras\AppData\Local\Temp\ipykernel_3184\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#Only KZ races, 50km & mi, 2020

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 7461181               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461182               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461183               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461184               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461185               Avalon Benefit 50-Mile Run (USA)                  50mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                               9           9:53:05 h  *Middleville, MI
# 56                               9          11:09:35 h     *Waterloo, ON
# 57                               9          11:33:00 h    *Kitchener, ON
# 58                               9          11:38:17 h        *Utica, MI
# 59                               9          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 7461181                         92          11:59:37 h               NaN
# 7461182                         92          12:01:41 h               NaN
# 7461183                         92          12:03:26 h               NaN
# 7461184                         92          12:03:26 h               NaN
# 7461185                         92          12:05:59 h               NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 7461181             USA                 1941.0              M
# 7461182             USA                 1932.0              M
# 7461183             USA                 1934.0              F
# 7461184             USA                 1951.0              F
# 7461185             USA                 1947.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141          55
# 56                       W40                 7.211          56
# 57                       M40                 6.967          57
# 58                       M23                 6.914          58
# 59                       M23                 6.738          59
# ...                      ...                   ...         ...
# 7461181                  M50                6709.0     1045603
# 7461182                  M60                6690.0     1070463
# 7461183                  W60                6674.0      416139
# 7461184                  W40                6674.0     1098098
# 7461185                  W45                6650.0     1626367
#
# [352181 rows x 13 columns]

# %%
df[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461181                  50mi                         92          11:59:37 h
# 7461182                  50mi                         92          12:01:41 h
# 7461183                  50mi                         92          12:03:26 h
# 7461184                  50mi                         92          12:03:26 h
# 7461185                  50mi                         92          12:05:59 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461181                 NaN             USA                 1941.0
# 7461182                 NaN             USA                 1932.0
# 7461183                 NaN             USA                 1934.0
# 7461184                 NaN             USA                 1951.0
# 7461185                 NaN             USA                 1947.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461181              M                  M50                6709.0     1045603
# 7461182              M                  M60                6690.0     1070463
# 7461183              F                  W60                6674.0      416139
# 7461184              F                  W40                6674.0     1098098
# 7461185              F                  W45                6650.0     1626367
#
# [1874790 rows x 13 columns]

# %%
df[df['Event distance/length'].isin(['50km', '50mi']) & (df['Year of event'] == 2022)]
# Out:
#          Year of event Event dates                             Event name  \
# 3138208           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138209           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138210           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138211           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# 3138212           2022  12.03.2022  Bel Monte 50 Mile Endurance Run (USA)
# ...                ...         ...                                    ...
# 3609801           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609802           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609803           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609804           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
# 3609805           2022  16.10.2022     Tussey Mountainback 50 Miler (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3138208                  50mi                         49           7:53:36 h
# 3138209                  50mi                         49           8:14:24 h
# 3138210                  50mi                         49           8:19:16 h
# 3138211                  50mi                         49           8:23:49 h
# 3138212                  50mi                         49           8:41:37 h
# ...                       ...                        ...                 ...
# 3609801                  50mi                         35          11:16:08 h
# 3609802                  50mi                         35          11:27:05 h
# 3609803                  50mi                         35          11:46:34 h
# 3609804                  50mi                         35          11:55:29 h
# 3609805                  50mi                         35          12:14:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3138208          *Boston, MA             USA                 1994.0
# 3138209       *Charlotte, NC             USA                 1990.0
# 3138210      *Kannapolis, NC             USA                 1979.0
# 3138211         *Raleigh, NC             USA                 1994.0
# 3138212      *Washington, DC             USA                 1997.0
# ...                      ...             ...                    ...
# 3609801  *Peachtree City, GA             USA                 1968.0
# 3609802         *Newport, PA             USA                 1959.0
# 3609803      *Flemington, NJ             USA                 1955.0
# 3609804       *Arlington, VA             USA                 1965.0
# 3609805       *Johnstown, PA             USA                 1981.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3138208              M                  M23                10.194      839364
# 3138209              M                  M23                 9.765      366598
# 3138210              M                  M40                  9.67      553476
# 3138211              M                  M23                 9.583      807555
# 3138212              M                  M23                 9.256      947348
# ...                ...                  ...                   ...         ...
# 3609801              M                  M50                 7.141     1044739
# 3609802              M                  M60                 7.027       50971
# 3609803              F                  W65                 6.833       73152
# 3609804              M                  M55                 6.748      970133
# 3609805              F                  W40                 6.575      723380
#
# [111250 rows x 13 columns]

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'KAZ']
# Out:
#          Year of event Event dates          Event name Event distance/length  \
# 312803            2018  07.05.2018  Tengri Ultra (KAZ)                  70km
# 312804            2018  07.05.2018  Tengri Ultra (KAZ)                  70km
# 312805            2018  07.05.2018  Tengri Ultra (KAZ)                  70km
# 312806            2018  07.05.2018  Tengri Ultra (KAZ)                  70km
# 312807            2018  07.05.2018  Tengri Ultra (KAZ)                  70km
# ...                ...         ...                 ...                   ...
# 6510989           2015  09.05.2015  Tengri Ultra (KAZ)                52.3km
# 6510990           2015  09.05.2015  Tengri Ultra (KAZ)                52.3km
# 6510991           2015  09.05.2015  Tengri Ultra (KAZ)                52.3km
# 6510992           2015  09.05.2015  Tengri Ultra (KAZ)                52.3km
# 6510993           2015  09.05.2015  Tengri Ultra (KAZ)                52.3km
#
#          Event number of finishers Athlete performance Athlete club  \
# 312803                          64           6:25:34 h          NaN
# 312804                          64           6:47:59 h          NaN
# 312805                          64           7:17:06 h          NaN
# 312806                          64           7:20:15 h          NaN
# 312807                          64           7:32:55 h          NaN
# ...                            ...                 ...          ...
# 6510989                         35          10:05:28 h          NaN
# 6510990                         35          10:12:23 h          NaN
# 6510991                         35          11:36:47 h          NaN
# 6510992                         35          11:36:49 h          NaN
# 6510993                         35          11:36:54 h          NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 312803              RUS                 1983.0              M
# 312804              HUN                 1988.0              M
# 312805              RUS                 1990.0              F
# 312806              ESP                 1981.0              M
# 312807              KAZ                 1986.0              M
# ...                 ...                    ...            ...
# 6510989             KAZ                 1985.0              M
# 6510990             KAZ                 1986.0              M
# 6510991             KAZ                 1995.0              M
# 6510992             KAZ                 1982.0              F
# 6510993             KAZ                 1988.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 312803                   M23                10.893      151462
# 312804                   M23                10.295      214512
# 312805                   W23                 9.609      214513
# 312806                   M35                  9.54      109970
# 312807                   M23                 9.273      214514
# ...                      ...                   ...         ...
# 6510989                  M23                 5.183     1488767
# 6510990                  M23                 5.124      292798
# 6510991                 MU23                 4.504     1488768
# 6510992                  W23                 4.503     1488769
# 6510993                  W23                 4.503     1488770
#
# [796 rows x 13 columns]

# %%
df2 = df[df['Event distance/length'].isin(['50km', '52.3km']) & (df['Year of event'] == 2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'KAZ')]

# %%
df2.head(3)
# Out:
#         year    race_day         race_name race_length  \
# 468571  2018  25.08.2018  Irbis Race 2018         50km
# 468572  2018  25.08.2018  Irbis Race 2018         50km
# 468573  2018  25.08.2018  Irbis Race 2018         50km
#
#         race_number_of_finishers athlete_performance athlete_country  \
# 468571                       111             6:02:10             KAZ
# 468572                       111             6:15:09             ESP
# 468573                       111             7:07:39             KAZ
#
#        athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 468571              M                  8.283      292741           32
# 468572              M                  7.997      292742           30
# 468573              M                  7.015      292743           37

# %%
df2['race_name'] = df2['race_name'].str.split('(').str.get(0)

# %%
df2.head(10)
# Out:
#         year    race_day         race_name race_length  \
# 468571  2018  25.08.2018  Irbis Race 2018         50km
# 468572  2018  25.08.2018  Irbis Race 2018         50km
# 468573  2018  25.08.2018  Irbis Race 2018         50km
# 468574  2018  25.08.2018  Irbis Race 2018         50km
# 468575  2018  25.08.2018  Irbis Race 2018         50km
# 468576  2018  25.08.2018  Irbis Race 2018         50km
# 468577  2018  25.08.2018  Irbis Race 2018         50km
# 468578  2018  25.08.2018  Irbis Race 2018         50km
# 468579  2018  25.08.2018  Irbis Race 2018         50km
# 468580  2018  25.08.2018  Irbis Race 2018         50km
#
#         race_number_of_finishers athlete_performance athlete_country  \
# 468571                       111             6:02:10             KAZ
# 468572                       111             6:15:09             ESP
# 468573                       111             7:07:39             KAZ
# 468574                       111             7:49:58             KAZ
# 468575                       111             7:50:34             KAZ
# 468576                       111             7:52:59             KAZ
# 468577                       111             8:19:57             KAZ
# 468578                       111             8:25:55             KAZ
# 468579                       111             8:35:56             KAZ
# 468580                       111             8:54:52             KAZ
#
#        athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 468571              M                  8.283      292741           32
# 468572              M                  7.997      292742           30
# 468573              M                  7.015      292743           37
# 468574              M                  6.383      292744           30
# 468575              M                  6.375      292745           38
# 468576              M                  6.343      292746           35
# 468577              M                  6.001      292747           27
# 468578              M                  5.930      292748           52
# 468579              M                  5.815      292749           29
# 468580              M                  5.609      214516           35

# %%
df2['athelete_age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\yeras\AppData\Local\Temp\ipykernel_3184\3538669710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athelete_age'] = 2020 - df2['Athlete year of birth']

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\yeras\AppData\Local\Temp\ipykernel_3184\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(10)
# Out:
#         Year of event Event dates        Event name Event distance/length  \
# 468571           2018  25.08.2018  Irbis Race 2018                   50km
# 468572           2018  25.08.2018  Irbis Race 2018                   50km
# 468573           2018  25.08.2018  Irbis Race 2018                   50km
# 468574           2018  25.08.2018  Irbis Race 2018                   50km
# 468575           2018  25.08.2018  Irbis Race 2018                   50km
# 468576           2018  25.08.2018  Irbis Race 2018                   50km
# 468577           2018  25.08.2018  Irbis Race 2018                   50km
# 468578           2018  25.08.2018  Irbis Race 2018                   50km
# 468579           2018  25.08.2018  Irbis Race 2018                   50km
# 468580           2018  25.08.2018  Irbis Race 2018                   50km
#
#         Event number of finishers Athlete performance Athlete club  \
# 468571                        111             6:02:10          NaN
# 468572                        111             6:15:09          NaN
# 468573                        111             7:07:39          NaN
# 468574                        111             7:49:58          NaN
# 468575                        111             7:50:34          NaN
# 468576                        111             7:52:59          NaN
# 468577                        111             8:19:57          NaN
# 468578                        111             8:25:55          NaN
# 468579                        111             8:35:56          NaN
# 468580                        111             8:54:52          NaN
#
#        Athlete country  Athlete year of birth Athlete gender  \
# 468571             KAZ                 1988.0              M
# 468572             ESP                 1990.0              M
# 468573             KAZ                 1983.0              M
# 468574             KAZ                 1990.0              M
# 468575             KAZ                 1982.0              M
# 468576             KAZ                 1985.0              M
# 468577             KAZ                 1993.0              M
# 468578             KAZ                 1968.0              M
# 468579             KAZ                 1991.0              M
# 468580             KAZ                 1985.0              M
#
#        Athlete age category Athlete average speed  Athlete ID  athelete_age
# 468571                  M23                 8.283      292741          32.0
# 468572                  M23                 7.997      292742          30.0
# 468573                  M23                 7.015      292743          37.0
# 468574                  M23                 6.383      292744          30.0
# 468575                  M35                 6.375      292745          38.0
# 468576                  M23                 6.343      292746          35.0
# 468577                  M23                 6.001      292747          27.0
# 468578                  M45                  5.93      292748          52.0
# 468579                  M23                 5.815      292749          29.0
# 468580                  M23                 5.609      214516          35.0

# %%
#drop columns

# %%
df2 = df2.drop(['Athlete club', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head(10)
# Out:
#         Year of event Event dates        Event name Event distance/length  \
# 468571           2018  25.08.2018  Irbis Race 2018                   50km
# 468572           2018  25.08.2018  Irbis Race 2018                   50km
# 468573           2018  25.08.2018  Irbis Race 2018                   50km
# 468574           2018  25.08.2018  Irbis Race 2018                   50km
# 468575           2018  25.08.2018  Irbis Race 2018                   50km
# 468576           2018  25.08.2018  Irbis Race 2018                   50km
# 468577           2018  25.08.2018  Irbis Race 2018                   50km
# 468578           2018  25.08.2018  Irbis Race 2018                   50km
# 468579           2018  25.08.2018  Irbis Race 2018                   50km
# 468580           2018  25.08.2018  Irbis Race 2018                   50km
#
#         Event number of finishers Athlete performance Athlete country  \
# 468571                        111             6:02:10             KAZ
# 468572                        111             6:15:09             ESP
# 468573                        111             7:07:39             KAZ
# 468574                        111             7:49:58             KAZ
# 468575                        111             7:50:34             KAZ
# 468576                        111             7:52:59             KAZ
# 468577                        111             8:19:57             KAZ
# 468578                        111             8:25:55             KAZ
# 468579                        111             8:35:56             KAZ
# 468580                        111             8:54:52             KAZ
#
#        Athlete gender Athlete average speed  Athlete ID  athelete_age
# 468571              M                 8.283      292741          32.0
# 468572              M                 7.997      292742          30.0
# 468573              M                 7.015      292743          37.0
# 468574              M                 6.383      292744          30.0
# 468575              M                 6.375      292745          38.0
# 468576              M                 6.343      292746          35.0
# 468577              M                 6.001      292747          27.0
# 468578              M                  5.93      292748          52.0
# 468579              M                 5.815      292749          29.0
# 468580              M                 5.609      214516          35.0

# %%
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete country              0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athelete_age                 0
# dtype: int64

# %%
df2[df2.duplicates() == True]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3184\3239160751.py in ?()
# ----> 1 df2[df2.duplicates() == True]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
df2.reset_index(drop = True)
# Out:
#      Year of event Event dates        Event name Event distance/length  \
# 0             2018  25.08.2018  Irbis Race 2018                   50km
# 1             2018  25.08.2018  Irbis Race 2018                   50km
# 2             2018  25.08.2018  Irbis Race 2018                   50km
# 3             2018  25.08.2018  Irbis Race 2018                   50km
# 4             2018  25.08.2018  Irbis Race 2018                   50km
# ..             ...         ...               ...                   ...
# 106           2018  25.08.2018  Irbis Race 2018                   50km
# 107           2018  25.08.2018  Irbis Race 2018                   50km
# 108           2018  25.08.2018  Irbis Race 2018                   50km
# 109           2018  25.08.2018  Irbis Race 2018                   50km
# 110           2018  25.08.2018  Irbis Race 2018                   50km
#
#      Event number of finishers Athlete performance Athlete country  \
# 0                          111             6:02:10             KAZ
# 1                          111             6:15:09             ESP
# 2                          111             7:07:39             KAZ
# 3                          111             7:49:58             KAZ
# 4                          111             7:50:34             KAZ
# ..                         ...                 ...             ...
# 106                        111            15:58:25             KAZ
# 107                        111            15:59:03             CZE
# 108                        111            17:18:42             KAZ
# 109                        111            17:18:48             KAZ
# 110                        111            17:54:11             KAZ
#
#     Athlete gender Athlete average speed  Athlete ID  athelete_age
# 0                M                 8.283      292741          32.0
# 1                M                 7.997      292742          30.0
# 2                M                 7.015      292743          37.0
# 3                M                 6.383      292744          30.0
# 4                M                 6.375      292745          38.0
# ..             ...                   ...         ...           ...
# 106              M                  3.13      292822          24.0
# 107              F                 3.128      292823          44.0
# 108              M                 2.888      292824          41.0
# 109              M                 2.888      292825          62.0
# 110              M                 2.793      292826          41.0
#
# [111 rows x 11 columns]

# %%
df2['athelete_age'] = df2['athelete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete country               object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athelete_age                   int32
# dtype: object

# %%
df2.head()
# Out:
#         Year of event Event dates        Event name Event distance/length  \
# 468571           2018  25.08.2018  Irbis Race 2018                   50km
# 468572           2018  25.08.2018  Irbis Race 2018                   50km
# 468573           2018  25.08.2018  Irbis Race 2018                   50km
# 468574           2018  25.08.2018  Irbis Race 2018                   50km
# 468575           2018  25.08.2018  Irbis Race 2018                   50km
#
#         Event number of finishers Athlete performance Athlete country  \
# 468571                        111             6:02:10             KAZ
# 468572                        111             6:15:09             ESP
# 468573                        111             7:07:39             KAZ
# 468574                        111             7:49:58             KAZ
# 468575                        111             7:50:34             KAZ
#
#        Athlete gender  Athlete average speed  Athlete ID  athelete_age
# 468571              M                  8.283      292741            32
# 468572              M                  7.997      292742            30
# 468573              M                  7.015      292743            37
# 468574              M                  6.383      292744            30
# 468575              M                  6.375      292745            38

# %%
df2 = df2.rename(columns = {'Year of event':'year',
                            'Event dates':'race_day',
                            'Event name':'race_name',
                            'Event distance/length':'race_length',
                            'Event number of finishers':'race_number_of_finishers',
                            'Athlete performance':'athlete_performance',
                            'Athlete country':'athlete_country',
                            'Athlete gender':'athlete_gender',
                            'Athlete average speed':'athlete_average_speed',
                            'Athlete ID':'athlete_id',
                            'athelete_age':'athlete_age'
})

# %%
df2.head()
# Out:
#         year    race_day         race_name race_length  \
# 468571  2018  25.08.2018  Irbis Race 2018         50km
# 468572  2018  25.08.2018  Irbis Race 2018         50km
# 468573  2018  25.08.2018  Irbis Race 2018         50km
# 468574  2018  25.08.2018  Irbis Race 2018         50km
# 468575  2018  25.08.2018  Irbis Race 2018         50km
#
#         race_number_of_finishers athlete_performance athlete_country  \
# 468571                       111             6:02:10             KAZ
# 468572                       111             6:15:09             ESP
# 468573                       111             7:07:39             KAZ
# 468574                       111             7:49:58             KAZ
# 468575                       111             7:50:34             KAZ
#
#        athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 468571              M                  8.283      292741           32
# 468572              M                  7.997      292742           30
# 468573              M                  7.015      292743           37
# 468574              M                  6.383      292744           30
# 468575              M                  6.375      292745           38

# %%
#reorder

# %%
df3 = df3 = df2[['race_day', 'race_name', 'race_length', 'race_number_of_finishers', 'athlete_id', 'athlete_gender', 'athlete_age', 'athlete_country', 'athlete_performance', 'athlete_average_speed']]

# %%
df3.head()
# Out:
#           race_day         race_name race_length  race_number_of_finishers  \
# 468571  25.08.2018  Irbis Race 2018         50km                       111
# 468572  25.08.2018  Irbis Race 2018         50km                       111
# 468573  25.08.2018  Irbis Race 2018         50km                       111
# 468574  25.08.2018  Irbis Race 2018         50km                       111
# 468575  25.08.2018  Irbis Race 2018         50km                       111
#
#         athlete_id athlete_gender  athlete_age athlete_country  \
# 468571      292741              M           32             KAZ
# 468572      292742              M           30             ESP
# 468573      292743              M           37             KAZ
# 468574      292744              M           30             KAZ
# 468575      292745              M           38             KAZ
#
#        athlete_performance  athlete_average_speed
# 468571             6:02:10                  8.283
# 468572             6:15:09                  7.997
# 468573             7:07:39                  7.015
# 468574             7:49:58                  6.383
# 468575             7:50:34                  6.375

# %%
df3[df3['athlete_id'] == 292743]
# Out:
#           race_day         race_name race_length  race_number_of_finishers  \
# 468573  25.08.2018  Irbis Race 2018         50km                       111
#
#         athlete_id athlete_gender  athlete_age athlete_country  \
# 468573      292743              M           37             KAZ
#
#        athlete_performance  athlete_average_speed
# 468573             7:07:39                  7.015

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50km']['athlete_average_speed'])
# Out:
# C:\Users\yeras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.violinplot(data = df3, x ='race_length', y = 'athlete_average_speed', hue = 'athlete_gender', split = True, inner = 'quart', linewidth = 1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data = df3, x = 'athlete_age', y = 'athlete_average_speed', hue = 'athlete_gender')
# Out:
# C:\Users\yeras\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df3.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 4.245667
#              M                 4.430366
# Name: athlete_average_speed, dtype: float64

# %%
df3.query('race_length == "50km"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False).query('count>5')
# Out:
#                  mean  count
# athlete_age
# 37           4.657429      7
# 35           4.613727     11
# 38           4.431857      7
# 33           4.179571      7
# 41           3.757714      7

# %%
df3.query('race_length == "50km"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = True).query('count>5')
# Out:
#                  mean  count
# athlete_age
# 41           3.757714      7
# 33           4.179571      7
# 38           4.431857      7
# 35           4.613727     11
# 37           4.657429      7

# %%
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3.head()
# Out:
#           race_day         race_name race_length  race_number_of_finishers  \
# 468571  25.08.2018  Irbis Race 2018         50km                       111
# 468572  25.08.2018  Irbis Race 2018         50km                       111
# 468573  25.08.2018  Irbis Race 2018         50km                       111
# 468574  25.08.2018  Irbis Race 2018         50km                       111
# 468575  25.08.2018  Irbis Race 2018         50km                       111
#
#         athlete_id athlete_gender  athlete_age athlete_country  \
# 468571      292741              M           32             KAZ
# 468572      292742              M           30             ESP
# 468573      292743              M           37             KAZ
# 468574      292744              M           30             KAZ
# 468575      292745              M           38             KAZ
#
#        athlete_performance  athlete_average_speed  race_month
# 468571             6:02:10                  8.283           8
# 468572             6:15:09                  7.997           8
# 468573             7:07:39                  7.015           8
# 468574             7:49:58                  6.383           8
# 468575             7:50:34                  6.375           8

# %%
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter')

# %%
df3.head(100)
# Out:
#           race_day         race_name race_length  race_number_of_finishers  \
# 468571  25.08.2018  Irbis Race 2018         50km                       111
# 468572  25.08.2018  Irbis Race 2018         50km                       111
# 468573  25.08.2018  Irbis Race 2018         50km                       111
# 468574  25.08.2018  Irbis Race 2018         50km                       111
# 468575  25.08.2018  Irbis Race 2018         50km                       111
# ...            ...               ...         ...                       ...
# 468666  25.08.2018  Irbis Race 2018         50km                       111
# 468667  25.08.2018  Irbis Race 2018         50km                       111
# 468668  25.08.2018  Irbis Race 2018         50km                       111
# 468669  25.08.2018  Irbis Race 2018         50km                       111
# 468670  25.08.2018  Irbis Race 2018         50km                       111
#
#         athlete_id athlete_gender  athlete_age athlete_country  \
# 468571      292741              M           32             KAZ
# 468572      292742              M           30             ESP
# 468573      292743              M           37             KAZ
# 468574      292744              M           30             KAZ
# 468575      292745              M           38             KAZ
# ...            ...            ...          ...             ...
# 468666      292813              M           42             KAZ
# 468667      292814              M           35             KAZ
# 468668      292815              M           40             GER
# 468669      292816              M           33             KAZ
# 468670      214554              M           28             USA
#
#        athlete_performance  athlete_average_speed  race_month race_season
# 468571             6:02:10                  8.283           8      Summer
# 468572             6:15:09                  7.997           8      Summer
# 468573             7:07:39                  7.015           8      Summer
# 468574             7:49:58                  6.383           8      Summer
# 468575             7:50:34                  6.375           8      Summer
# ...                    ...                    ...         ...         ...
# 468666            14:26:13                  3.463           8      Summer
# 468667            14:28:48                  3.453           8      Summer
# 468668            14:28:58                  3.452           8      Summer
# 468669            14:46:13                  3.385           8      Summer
# 468670            15:11:43                  3.290           8      Summer
#
# [100 rows x 12 columns]

# %%
df3.groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Summer       4.400414    111
